# %%
# Import all necessary libraries 

import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import json
import csv
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
sns.set()

# allowing all the columns to be visualized
pd.options.display.max_columns = None

# rendering all graphics straight out of the notebook
# %matplotlib inline

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
pd.set_option('display.max_rows', None)

# %%
fd= pd.read_csv("https://raw.githubusercontent.com/hippoghost/data-science-projects/master/adulthood/adulthood_dataframe.csv")

# %% [markdown]
# ## EXPLORING DATA

# %% [markdown]
# ## Inspecting DataFrame

# %%
full=fd

# %%
full.shape
# Out:
# (2897, 72)

# %%
full.head(1)
# Out:
#                                 tr_available_markets  tr_disc_number  \
# 0  ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT...               1
#
#    tr_duration_ms  tr_explicit  \
# 0           38826        False
#
#                                              tr_href                   tr_id  \
# 0  https://api.spotify.com/v1/tracks/6gUejkYukr6D...  6gUejkYukr6D9MfZaJawPS
#
#    tr_is_local                                            tr_name  \
# 0        False  Churchill’s Speech - Live in Mexico City, Pala...
#
#    tr_popularity                                     tr_preview_url  \
# 0             41  https://p.scdn.co/mp3-preview/501552516390e845...
#
#    tr_track_number tr_type                                tr_uri  \
# 0                1   track  spotify:track:6gUejkYukr6D9MfZaJawPS
#
#        tr_track_artist_id tr_album_album_type  \
# 0  6mdiAmATAx73kdxrNrnlao               album
#
#                                     tr_album_artists  \
# 0  [{'external_urls': {'spotify': 'https://open.s...
#
#                           tr_album_available_markets  \
# 0  ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT...
#
#                       tr_album_external_urls_spotify  \
# 0  https://open.spotify.com/album/6IVkf5av5jnraZp...
#
#                                        tr_album_href             tr_album_id  \
# 0  https://api.spotify.com/v1/albums/6IVkf5av5jnr...  6IVkf5av5jnraZpLPszoZR
#
#                                      tr_album_images  \
# 0  [{'height': 640, 'url': 'https://i.scdn.co/ima...
#
#                                        tr_album_name tr_album_release_date  \
# 0  Nights of the Dead, Legacy of the Beast: Live ...            2020-11-20
#
#   tr_album_release_date_precision  tr_album_total_tracks tr_album_type  \
# 0                             day                     17         album
#
#                            tr_album_uri tr_external_ids_isrc  \
# 0  spotify:album:6IVkf5av5jnraZpLPszoZR         GBCHB2000001
#
#                             tr_external_urls_spotify al_album_group  \
# 0  https://open.spotify.com/track/6gUejkYukr6D9Mf...          album
#
#   al_album_type                                         al_artists  \
# 0         album  [{'external_urls': {'spotify': 'https://open.s...
#
#                                 al_available_markets  \
# 0  ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT...
#
#                                              al_href                   al_id  \
# 0  https://api.spotify.com/v1/albums/6IVkf5av5jnr...  6IVkf5av5jnraZpLPszoZR
#
#                                            al_images  \
# 0  [{'height': 640, 'url': 'https://i.scdn.co/ima...
#
#                                              al_name al_release_date  \
# 0  Nights of the Dead, Legacy of the Beast: Live ...      2020-11-20
#
#   al_release_date_precision  al_total_tracks al_type  \
# 0                       day             17.0   album
#
#                                  al_uri            al_artist_id  \
# 0  spotify:album:6IVkf5av5jnraZpLPszoZR  6mdiAmATAx73kdxrNrnlao
#
#                             al_external_urls_spotify  \
# 0  https://open.spotify.com/album/6IVkf5av5jnraZp...
#
#                                              ar_href                   ar_id  \
# 0  https://api.spotify.com/v1/artists/6mdiAmATAx7...  6mdiAmATAx73kdxrNrnlao
#
#                                            ar_images      ar_name  \
# 0  [{'height': 640, 'url': 'https://i.scdn.co/ima...  Iron Maiden
#
#    ar_popularity ar_type                                 ar_uri  \
# 0           77.0  artist  spotify:artist:6mdiAmATAx73kdxrNrnlao
#
#                             ar_external_urls_spotify  ar_followers_href  \
# 0  https://open.spotify.com/artist/6mdiAmATAx73kd...                NaN
#
#    ar_followers_total  tf_danceability  tf_energy  tf_key  tf_loudness  \
# 0           6201079.0            0.338      0.904       5      -12.851
#
#    tf_mode  tf_speechiness  tf_acousticness  tf_instrumentalness  tf_liveness  \
# 0        0           0.161            0.433                0.134         0.91
#
#    tf_valence  tf_tempo         tf_type                   tf_id  \
# 0      0.0394    85.128  audio_features  6gUejkYukr6D9MfZaJawPS
#
#                                  tf_uri  \
# 0  spotify:track:6gUejkYukr6D9MfZaJawPS
#
#                                        tf_track_href  \
# 0  https://api.spotify.com/v1/tracks/6gUejkYukr6D...
#
#                                      tf_analysis_url  tf_duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/6gUe...           38827
#
#    tf_time_signature
# 0                  3

# %%
full.tail(1)
# Out:
#      tr_available_markets  tr_disc_number  tr_duration_ms  tr_explicit  \
# 2896         ['CA', 'US']               5          154795        False
#
#                                                 tr_href  \
# 2896  https://api.spotify.com/v1/tracks/31ff2s4BUKVx...
#
#                        tr_id  tr_is_local  \
# 2896  31ff2s4BUKVx0i0EKHM2Gc        False
#
#                                                 tr_name  tr_popularity  \
# 2896  (Anesthesia) – Pulling Teeth (Live at The Keys...             14
#
#                                          tr_preview_url  tr_track_number  \
# 2896  https://p.scdn.co/mp3-preview/d7041eea208c0bf5...                9
#
#      tr_type                                tr_uri      tr_track_artist_id  \
# 2896   track  spotify:track:31ff2s4BUKVx0i0EKHM2Gc  2ye2Wgw4gimLv2eAKyk1NB
#
#      tr_album_album_type                                   tr_album_artists  \
# 2896               album  [{'external_urls': {'spotify': 'https://open.s...
#
#      tr_album_available_markets  \
# 2896               ['CA', 'US']
#
#                          tr_album_external_urls_spotify  \
# 2896  https://open.spotify.com/album/7GttoSWxEi5lZvI...
#
#                                           tr_album_href  \
# 2896  https://api.spotify.com/v1/albums/7GttoSWxEi5l...
#
#                  tr_album_id  \
# 2896  7GttoSWxEi5lZvIWeSrh6n
#
#                                         tr_album_images  \
# 2896  [{'height': 640, 'url': 'https://i.scdn.co/ima...
#
#                        tr_album_name tr_album_release_date  \
# 2896  Kill 'Em All (Deluxe Remaster)            1983-07-25
#
#      tr_album_release_date_precision  tr_album_total_tracks tr_album_type  \
# 2896                             day                     54         album
#
#                               tr_album_uri tr_external_ids_isrc  \
# 2896  spotify:album:7GttoSWxEi5lZvIWeSrh6n         QMKHM1600066
#
#                                tr_external_urls_spotify al_album_group  \
# 2896  https://open.spotify.com/track/31ff2s4BUKVx0i0...          album
#
#      al_album_type                                         al_artists  \
# 2896         album  [{'external_urls': {'spotify': 'https://open.s...
#
#      al_available_markets                                            al_href  \
# 2896         ['CA', 'US']  https://api.spotify.com/v1/albums/7GttoSWxEi5l...
#
#                        al_id  \
# 2896  7GttoSWxEi5lZvIWeSrh6n
#
#                                               al_images  \
# 2896  [{'height': 640, 'url': 'https://i.scdn.co/ima...
#
#                              al_name al_release_date  \
# 2896  Kill 'Em All (Deluxe Remaster)      1983-07-25
#
#      al_release_date_precision  al_total_tracks al_type  \
# 2896                       day             54.0   album
#
#                                     al_uri            al_artist_id  \
# 2896  spotify:album:7GttoSWxEi5lZvIWeSrh6n  2ye2Wgw4gimLv2eAKyk1NB
#
#                                al_external_urls_spotify  \
# 2896  https://open.spotify.com/album/7GttoSWxEi5lZvI...
#
#                                                 ar_href  \
# 2896  https://api.spotify.com/v1/artists/2ye2Wgw4gim...
#
#                        ar_id  \
# 2896  2ye2Wgw4gimLv2eAKyk1NB
#
#                                               ar_images    ar_name  \
# 2896  [{'height': 640, 'url': 'https://i.scdn.co/ima...  Metallica
#
#       ar_popularity ar_type                                 ar_uri  \
# 2896           85.0  artist  spotify:artist:2ye2Wgw4gimLv2eAKyk1NB
#
#                                ar_external_urls_spotify  ar_followers_href  \
# 2896  https://open.spotify.com/artist/2ye2Wgw4gimLv2...                NaN
#
#       ar_followers_total  tf_danceability  tf_energy  tf_key  tf_loudness  \
# 2896          17257877.0             0.22      0.877       2        -7.49
#
#       tf_mode  tf_speechiness  tf_acousticness  tf_instrumentalness  \
# 2896        1            0.06            0.689                 0.84
#
#       tf_liveness  tf_valence  tf_tempo         tf_type  \
# 2896        0.868        0.55   101.343  audio_features
#
#                        tf_id                                tf_uri  \
# 2896  31ff2s4BUKVx0i0EKHM2Gc  spotify:track:31ff2s4BUKVx0i0EKHM2Gc
#
#                                           tf_track_href  \
# 2896  https://api.spotify.com/v1/tracks/31ff2s4BUKVx...
#
#                                         tf_analysis_url  tf_duration_ms  \
# 2896  https://api.spotify.com/v1/audio-analysis/31ff...          154796
#
#       tf_time_signature
# 2896                  4

# %%
#full.info()

# %%
#full.dtypes

# %% [markdown]
# ## Trimming redundant columns

# %%
full['ar_name'].unique()
# Out:
# array(['Iron Maiden', nan, 'Bruce Dickinson', 'Blind Guardian',
#        'Iced Earth', 'Demons & Wizards', 'Theatre Of Tragedy',
#        'Metallica'], dtype=object)

# %%
#Using the columns attribute to check DataFrame's columns

full.columns
# Out:
# Index(['tr_available_markets', 'tr_disc_number', 'tr_duration_ms',
#        'tr_explicit', 'tr_href', 'tr_id', 'tr_is_local', 'tr_name',
#        'tr_popularity', 'tr_preview_url', 'tr_track_number', 'tr_type',
#        'tr_uri', 'tr_track_artist_id', 'tr_album_album_type',
#        'tr_album_artists', 'tr_album_available_markets',
#        'tr_album_external_urls_spotify', 'tr_album_href', 'tr_album_id',
#        'tr_album_images', 'tr_album_name', 'tr_album_release_date',
#        'tr_album_release_date_precision', 'tr_album_total_tracks',
#        'tr_album_type', 'tr_album_uri', 'tr_external_ids_isrc',
#        'tr_external_urls_spotify', 'al_album_group', 'al_album_type',
#        'al_artists', 'al_available_markets', 'al_href', 'al_id', 'al_images',
#        'al_name', 'al_release_date', 'al_release_date_precision',
#        'al_total_tracks', 'al_type', 'al_uri', 'al_artist_id',
#        'al_external_urls_spotify', 'ar_href', 'ar_id', 'ar_images', 'ar_name',
#        'ar_popularity', 'ar_type', 'ar_uri', 'ar_external_urls_spotify',
#        'ar_followers_href', 'ar_followers_total', 'tf_danceability',
#        'tf_energy', 'tf_key', 'tf_loudness', 'tf_mode', 'tf_speechiness',
#        'tf_acousticness', 'tf_instrumentalness', 'tf_liveness', 'tf_valence',
#        'tf_tempo', 'tf_type', 'tf_id', 'tf_uri', 'tf_track_href',
#        'tf_analysis_url', 'tf_duration_ms', 'tf_time_signature'],
#       dtype='object')

# %%
# dropping columns that won't be used for analysis

full=full.drop(columns=['tr_available_markets', 'tr_disc_number',
       'tr_href', 'tr_id', 'tr_is_local', 'tr_preview_url', 'tr_type',
       'tr_uri', 'tr_track_artist_id', 'tr_album_album_type',
       'tr_album_artists', 'tr_album_available_markets',
       'tr_album_external_urls_spotify', 'tr_album_href', 'tr_album_id',
       'tr_album_images', 'tr_album_name', 'tr_album_release_date',
       'tr_album_release_date_precision', 'tr_album_total_tracks',
       'tr_album_type', 'tr_album_uri', 'tr_external_ids_isrc',
       'tr_external_urls_spotify', 'al_album_group',
       'al_artists', 'al_available_markets', 'al_href', 'al_id', 'al_images','al_release_date_precision',
                       'al_type', 'al_uri', 'al_artist_id',
       'al_external_urls_spotify', 'ar_href', 'ar_id', 'ar_images','ar_type', 'ar_uri', 'ar_external_urls_spotify',
       'ar_followers_href','tf_type', 'tf_id', 'tf_uri',
        'tf_duration_ms' ,'tf_track_href','tf_analysis_url','tf_time_signature'])
#'

# %% [markdown]
# ### Rearranging columns for convenience of analysis

# %%
#checking columns sequence

cols = list(full.columns.values)
cols
# Out:
# ['tr_duration_ms',
#  'tr_explicit',
#  'tr_name',
#  'tr_popularity',
#  'tr_track_number',
#  'al_album_type',
#  'al_name',
#  'al_release_date',
#  'al_total_tracks',
#  'ar_name',
#  'ar_popularity',
#  'ar_followers_total',
#  'tf_danceability',
#  'tf_energy',
#  'tf_key',
#  'tf_loudness',
#  'tf_mode',
#  'tf_speechiness',
#  'tf_acousticness',
#  'tf_instrumentalness',
#  'tf_liveness',
#  'tf_valence',
#  'tf_tempo']

# %%
# rearranging columns

full = full[['ar_name','ar_popularity','tr_name','tr_popularity','al_name','al_release_date',
                     'al_total_tracks','al_album_type','ar_followers_total','tr_duration_ms',
                     'tr_track_number','tf_danceability','tf_energy','tf_loudness','tf_speechiness','tf_acousticness',
                    'tf_instrumentalness','tf_liveness','tf_valence','tf_tempo','tf_key','tf_mode','tr_explicit']]

# %%
# Checking dataset
full.head(1)
# Out:
#        ar_name  ar_popularity  \
# 0  Iron Maiden           77.0
#
#                                              tr_name  tr_popularity  \
# 0  Churchill’s Speech - Live in Mexico City, Pala...             41
#
#                                              al_name al_release_date  \
# 0  Nights of the Dead, Legacy of the Beast: Live ...      2020-11-20
#
#    al_total_tracks al_album_type  ar_followers_total  tr_duration_ms  \
# 0             17.0         album           6201079.0           38826
#
#    tr_track_number  tf_danceability  tf_energy  tf_loudness  tf_speechiness  \
# 0                1            0.338      0.904      -12.851           0.161
#
#    tf_acousticness  tf_instrumentalness  tf_liveness  tf_valence  tf_tempo  \
# 0            0.433                0.134         0.91      0.0394    85.128
#
#    tf_key  tf_mode  tr_explicit
# 0       5        0        False

# %%
#inspecting DataFrame's shape, after removing unessecary information

full.shape
# Out:
# (2897, 23)

# %% [markdown]
# ##  Descriptive statistics

# %%
full.describe()
# Out:
#        ar_popularity  tr_popularity  al_total_tracks  ar_followers_total  \
# count    2430.000000    2897.000000      2430.000000        2.430000e+03
# mean       69.677366      24.526061        29.629218        7.356073e+06
# std        14.425074      15.030934        35.869778        7.394296e+06
# min        46.000000       0.000000         6.000000        8.870800e+04
# 25%        56.000000      15.000000        11.000000        4.228070e+05
# 50%        77.000000      23.000000        17.000000        6.201079e+06
# 75%        85.000000      35.000000        26.000000        1.725788e+07
# max        85.000000      80.000000       147.000000        1.725788e+07
#
#        tr_duration_ms  tr_track_number  tf_danceability    tf_energy  \
# count    2.897000e+03      2897.000000      2897.000000  2897.000000
# mean     3.362372e+05         6.857094         0.352973     0.870427
# std      1.318322e+05         4.617812         0.129665     0.158822
# min      1.632500e+04         1.000000         0.075100     0.053300
# 25%      2.558660e+05         3.000000         0.257000     0.841000
# 50%      3.192400e+05         6.000000         0.326000     0.931000
# 75%      4.048000e+05         9.000000         0.446000     0.970000
# max      1.168906e+06        31.000000         0.774000     0.999000
#
#        tf_loudness  tf_speechiness  tf_acousticness  tf_instrumentalness  \
# count  2897.000000     2897.000000      2897.000000          2897.000000
# mean     -6.839827        0.097163         0.051720             0.183767
# std       2.770297        0.073721         0.161107             0.285296
# min     -29.042000        0.024200         0.000001             0.000000
# 25%      -7.843000        0.049000         0.000131             0.000741
# 50%      -6.384000        0.077000         0.001160             0.019000
# 75%      -5.205000        0.122000         0.010400             0.249000
# max      -0.463000        0.921000         0.995000             0.988000
#
#        tf_liveness   tf_valence     tf_tempo       tf_key     tf_mode
# count  2897.000000  2897.000000  2897.000000  2897.000000  2897.00000
# mean      0.412118     0.307665   123.517999     5.336210     0.52399
# std       0.340983     0.185042    30.077134     3.435903     0.49951
# min       0.021300     0.000000    50.384000     0.000000     0.00000
# 25%       0.115000     0.159000    99.366000     2.000000     0.00000
# 50%       0.262000     0.280000   119.567000     5.000000     1.00000
# 75%       0.769000     0.430000   142.503000     8.000000     1.00000
# max       1.000000     0.970000   207.012000    11.000000     1.00000

# %% [markdown]
# ### Checking Skew

# %%
full[["ar_popularity","tr_popularity","al_total_tracks",
"ar_followers_total","tr_track_number","tr_duration_ms","tf_danceability","tf_energy","tf_loudness",
"tf_speechiness","tf_acousticness","tf_instrumentalness","tf_liveness","tf_valence","tf_tempo"]].skew()
# Out:
# ar_popularity         -0.297142
# tr_popularity          0.383254
# al_total_tracks        2.518765
# ar_followers_total     0.432014
# tr_track_number        1.147931
# tr_duration_ms         1.050327
# tf_danceability        0.511019
# tf_energy             -2.316815
# tf_loudness           -2.185625
# tf_speechiness         3.540047
# tf_acousticness        4.088503
# tf_instrumentalness    1.466167
# tf_liveness            0.600967
# tf_valence             0.680616
# tf_tempo               0.443862
# dtype: float64

# %% [markdown]
# ### Checking Kurtosis

# %%
full[["ar_popularity","tr_popularity","al_total_tracks",
"ar_followers_total","tr_duration_ms","tr_track_number","tf_danceability","tf_energy","tf_loudness",
"tf_speechiness","tf_acousticness","tf_instrumentalness","tf_liveness","tf_valence","tf_tempo"]].kurtosis()
# Out:
# ar_popularity          -1.541831
# tr_popularity          -0.147956
# al_total_tracks         5.115022
# ar_followers_total     -1.566289
# tr_duration_ms          4.544823
# tr_track_number         1.816433
# tf_danceability        -0.488331
# tf_energy               5.815574
# tf_loudness             8.215857
# tf_speechiness         24.872391
# tf_acousticness        16.776788
# tf_instrumentalness     0.692326
# tf_liveness            -1.290737
# tf_valence             -0.049289
# tf_tempo               -0.557692
# dtype: float64

# %%
#Renaming columns for convenience

full_renamed = full.rename(columns = {'tf_danceability': 'danceability', 'tf_energy': 'energy',
                                     'tf_loudness':'loudness','tf_speechiness':'speechiness','tf_acousticness':'acousticness',
                                     'tf_liveness':'liveness','tf_valence':'valence','tf_tempo':'tempo',
                                     'tf_mode':'mode','tf_instrumentalness':'instrumentalness'}, inplace = False)

full_renamed.head(1)
# Out:
#        ar_name  ar_popularity  \
# 0  Iron Maiden           77.0
#
#                                              tr_name  tr_popularity  \
# 0  Churchill’s Speech - Live in Mexico City, Pala...             41
#
#                                              al_name al_release_date  \
# 0  Nights of the Dead, Legacy of the Beast: Live ...      2020-11-20
#
#    al_total_tracks al_album_type  ar_followers_total  tr_duration_ms  \
# 0             17.0         album           6201079.0           38826
#
#    tr_track_number  danceability  energy  loudness  speechiness  acousticness  \
# 0                1         0.338   0.904   -12.851        0.161         0.433
#
#    instrumentalness  liveness  valence   tempo  tf_key  mode  tr_explicit
# 0             0.134      0.91   0.0394  85.128       5     0        False

# %% [markdown]
# # Setting Index

# %%
# setting artist name as index

#index=full_renamed.set_index(["ar_name","al_name"]).sort_values(by="ar_name", ascending=True)
#index

# %% [markdown]
# # Identifying missing values

# %%
#using info method , getting a gist of the dataset

full_renamed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2897 entries, 0 to 2896
# Data columns (total 23 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ar_name             2430 non-null   object
#  1   ar_popularity       2430 non-null   float64
#  2   tr_name             2897 non-null   object
#  3   tr_popularity       2897 non-null   int64
#  4   al_name             2430 non-null   object
#  5   al_release_date     2430 non-null   object
#  6   al_total_tracks     2430 non-null   float64
#  7   al_album_type       2430 non-null   object
#  8   ar_followers_total  2430 non-null   float64
#  9   tr_duration_ms      2897 non-null   int64
#  10  tr_track_number     2897 non-null   int64
#  11  danceability        2897 non-null   float64
#  12  energy              2897 non-null   float64
#  13  loudness            2897 non-null   float64
#  14  speechiness         2897 non-null   float64
#  15  acousticness        2897 non-null   float64
#  16  instrumentalness    2897 non-null   float64
#  17  liveness            2897 non-null   float64
#  18  valence             2897 non-null   float64
#  19  tempo               2897 non-null   float64
#  20  tf_key              2897 non-null   int64
#  21  mode                2897 non-null   int64
#  22  tr_explicit         2897 non-null   bool
# dtypes: bool(1), float64(12), int64(5), object(5)
# memory usage: 500.9+ KB

# %% [markdown]
# # Total missing values

# %%
full_renamed.isnull().values.sum()
# Out:
# 3269

# %%
#another way of checking missing values
full_renamed.isna().values.sum()
# Out:
# 3269

# %%
#Creating a null dataframe

null_dataframe=full_renamed.isnull()

# %%
#find out missing values per column
null_dataframe.sum()
# Out:
# ar_name               467
# ar_popularity         467
# tr_name                 0
# tr_popularity           0
# al_name               467
# al_release_date       467
# al_total_tracks       467
# al_album_type         467
# ar_followers_total    467
# tr_duration_ms          0
# tr_track_number         0
# danceability            0
# energy                  0
# loudness                0
# speechiness             0
# acousticness            0
# instrumentalness        0
# liveness                0
# valence                 0
# tempo                   0
# tf_key                  0
# mode                    0
# tr_explicit             0
# dtype: int64

# %% [markdown]
# # Percentage of missing columns

# %%
percentage=null_dataframe.mean()*100

print('Percentage of Missing Values:\n',percentage)
# Out:
# Percentage of Missing Values:
#  ar_name               16.120124
# ar_popularity         16.120124
# tr_name                0.000000
# tr_popularity          0.000000
# al_name               16.120124
# al_release_date       16.120124
# al_total_tracks       16.120124
# al_album_type         16.120124
# ar_followers_total    16.120124
# tr_duration_ms         0.000000
# tr_track_number        0.000000
# danceability           0.000000
# energy                 0.000000
# loudness               0.000000
# speechiness            0.000000
# acousticness           0.000000
# instrumentalness       0.000000
# liveness               0.000000
# valence                0.000000
# tempo                  0.000000
# tf_key                 0.000000
# mode                   0.000000
# tr_explicit            0.000000
# dtype: float64

# %% [markdown]
# ### Better understanding of missing values comes with the visualization of the amount of missing values using missingno package
#
# ### missingno library provides functions for graphical analysis of missing data

# %%
#Visualizing the completness of the dataset , bar chart of missing values
import missingno as msno
msno.bar(full)

# %% [markdown]
# ## Visualize the locations of missing values
# ### it describes the nullity in the dataset and appears blank wherever there are missing values
# ### the sparkline on the right summarizes the general shape of data completness and points out the row with the
# ### minimum number of null values in the DataFrame and the total amount of columns

# %%
msno.matrix(full)

# %% [markdown]
# # Missingness HeatMap

# %%
msno.heatmap(full)

# %%
msno.dendrogram(full)

# %% [markdown]
# ## creating 3 null dataframes  out of the original to play around with missing values using machine learning imputing techniques and misc imputing techniques as well

# %%
null_dataframe=full_renamed
null_data_knn=full_renamed
null_data_mice=full_renamed

# %% [markdown]
# ## MACHINE LEARNING TECHNIQUES TO IMPUTE MISSING VALUES

# %% [markdown]
# ### Ordinal Encoding
#
# ### Convert non-missing categorical columns to ordinal values

# %%
#Automate encoding in all categorical columns of DataFrame

from sklearn.preprocessing import OrdinalEncoder
# Create an empty dictionary ordinal_enc_dict
ordinal_enc_dict = {}

for col_name in null_data_knn:
    # Create Ordinal encoder for col
    ordinal_enc_dict[col_name] = OrdinalEncoder()
    col = null_data_knn[col_name]
    
    # Select non-null values of col
    col_not_null = col[col.notnull()]
    reshaped_vals = col_not_null.values.reshape(-1, 1)
    encoded_vals = ordinal_enc_dict[col_name].fit_transform(reshaped_vals)
    
    # Store the values to non-null values of the column in users
    null_data_knn.loc[col.notnull(), col_name] = np.squeeze(encoded_vals)

# %%
null_data_knn.head(2)
# Out:
#        ar_name  ar_popularity  \
# 0  Iron Maiden           77.0
# 1  Iron Maiden           77.0
#
#                                              tr_name  tr_popularity  \
# 0  Churchill’s Speech - Live in Mexico City, Pala...             41
# 1  Aces High - Live in Mexico City, Palacio de lo...             43
#
#                                              al_name al_release_date  \
# 0  Nights of the Dead, Legacy of the Beast: Live ...      2020-11-20
# 1  Nights of the Dead, Legacy of the Beast: Live ...      2020-11-20
#
#    al_total_tracks al_album_type  ar_followers_total  tr_duration_ms  \
# 0             17.0         album           6201079.0           38826
# 1             17.0         album           6201079.0          298789
#
#    tr_track_number  danceability  energy  loudness  speechiness  acousticness  \
# 0                1         0.338   0.904   -12.851        0.161       0.43300
# 1                2         0.273   0.997    -4.956        0.126       0.00768
#
#    instrumentalness  liveness  valence    tempo  tf_key  mode  tr_explicit
# 0            0.1340     0.910   0.0394   85.128       5     0        False
# 1            0.0469     0.852   0.0704  127.267       7     1        False

# %% [markdown]
# ## KNN imputing method

# %%
#impute missing values , using KNN machine learning method,then reconvert to categorical ones

from fancyimpute import KNN

# Create KNN imputer
KNN_imputer = KNN()

# Impute and round the users DataFrame
null_data_knn.iloc[:, :] = np.round(KNN_imputer.complete(null_data_knn))

# Loop over the column names in users
for col_name in null_data_knn:
    
    # Reshape the data
    reshaped = null_data_knn[col_name].values.reshape(-1, 1)
    
    # Perform inverse transform of the ordinally encoded columns
    null_data_knn[col_name] = ordinal_enc_dict[col_name].inverse_transform(reshaped)
# Out:
# Imputing row 1/2897 with 0 missing, elapsed time: 2.547
# Imputing row 101/2897 with 0 missing, elapsed time: 2.560
# Imputing row 201/2897 with 0 missing, elapsed time: 2.567
# Imputing row 301/2897 with 0 missing, elapsed time: 2.574
# Imputing row 401/2897 with 0 missing, elapsed time: 2.575
# Imputing row 501/2897 with 0 missing, elapsed time: 2.582
# Imputing row 601/2897 with 7 missing, elapsed time: 2.585
# Imputing row 701/2897 with 0 missing, elapsed time: 2.591
# Imputing row 801/2897 with 0 missing, elapsed time: 2.608
# Imputing row 901/2897 with 0 missing, elapsed time: 2.630
# Imputing row 1001/2897 with 7 missing, elapsed time: 2.639
# Imputing row 1101/2897 with 0 missing, elapsed time: 2.656
# Imputing row 1201/2897 with 0 missing, elapsed time: 2.663
# Imputing row 1301/2897 with 0 missing, elapsed time: 2.664
# Imputing row 1401/2897 with 0 missing, elapsed time: 2.668
# Imputing row 1501/2897 with 0 missing, elapsed time: 2.672
# Imputing row 1601/2897 with 0 missing, elapsed time: 2.673
# Imputing row 1701/2897 with 0 missing, elapsed time: 2.674
# Imputing row 1801/2897 with 0 missing, elapsed time: 2.675
# Imputing row 1901/2897 with 0 missing, elapsed time: 2.676
# Imputing row 2001/2897 with 0 missing, elapsed time: 2.684
# Imputing row 2101/2897 with 7 missing, elapsed time: 2.688
# Imputing row 2201/2897 with 0 missing, elapsed time: 2.702
# Imputing row 2301/2897 with 7 missing, elapsed time: 2.715
# Imputing row 2401/2897 with 0 missing, elapsed time: 2.723
# Imputing row 2501/2897 with 0 missing, elapsed time: 2.736
# Imputing row 2601/2897 with 0 missing, elapsed time: 2.737
# Imputing row 2701/2897 with 0 missing, elapsed time: 2.738
# Imputing row 2801/2897 with 0 missing, elapsed time: 2.739

# %%
null_data_knn.head(2)
# Out:
#        ar_name  ar_popularity  \
# 0  Iron Maiden           77.0
# 1  Iron Maiden           77.0
#
#                                              tr_name  tr_popularity  \
# 0  Churchill’s Speech - Live in Mexico City, Pala...             41
# 1  Aces High - Live in Mexico City, Palacio de lo...             43
#
#                                              al_name al_release_date  \
# 0  Nights of the Dead, Legacy of the Beast: Live ...      2020-11-20
# 1  Nights of the Dead, Legacy of the Beast: Live ...      2020-11-20
#
#    al_total_tracks al_album_type  ar_followers_total  tr_duration_ms  \
# 0             17.0         album           6201079.0           38826
# 1             17.0         album           6201079.0          298789
#
#    tr_track_number  danceability  energy  loudness  speechiness  acousticness  \
# 0                1         0.338   0.904   -12.851        0.161       0.43300
# 1                2         0.273   0.997    -4.956        0.126       0.00768
#
#    instrumentalness  liveness  valence    tempo  tf_key  mode  tr_explicit
# 0            0.1340     0.910   0.0394   85.128       5     0        False
# 1            0.0469     0.852   0.0704  127.267       7     1        False

# %% [markdown]
# ## IterativeImputer imputing method

# %%
#Automate encoding in all categorical columns of DataFrame

from sklearn.preprocessing import OrdinalEncoder
# Create an empty dictionary ordinal_enc_dict
ordinal_enc_dict = {}

for col_name in null_data_mice:
    # Create Ordinal encoder for col
    ordinal_enc_dict[col_name] = OrdinalEncoder()
    col = null_data_mice[col_name]
    
    # Select non-null values of col
    col_not_null = col[col.notnull()]
    reshaped_vals = col_not_null.values.reshape(-1, 1)
    encoded_vals = ordinal_enc_dict[col_name].fit_transform(reshaped_vals)
    
    # Store the values to non-null values of the column in users
    null_data_mice.loc[col.notnull(), col_name] = np.squeeze(encoded_vals)

# %%
#impute missing values , using IterativeImputer machine learning method,then reconvert to categorical ones

# explicitly require this experimental feature
from sklearn.experimental import enable_iterative_imputer  

# now you can import normally from sklearn.impute
from sklearn.impute import IterativeImputer

#Multiple imputations by Chained Equations (MICE)
#MICE performs multiple regression for imputing, robust model for imputation

mice_impute = IterativeImputer()

# Impute and round the users DataFrame
null_data_mice.iloc[:, :] = np.round(mice_impute.fit_transform(null_data_mice))

# Loop over the column names in users
for col_name in null_data_mice:
    
    # Reshape the data
    reshaped = null_data_mice[col_name].values.reshape(-1, 1)
    
    # Perform inverse transform of the ordinally encoded columns
    null_data_mice[col_name] = ordinal_enc_dict[col_name].inverse_transform(reshaped)

# %%
null_data_mice.head(2)
# Out:
#        ar_name  ar_popularity  \
# 0  Iron Maiden           77.0
# 1  Iron Maiden           77.0
#
#                                              tr_name  tr_popularity  \
# 0  Churchill’s Speech - Live in Mexico City, Pala...             41
# 1  Aces High - Live in Mexico City, Palacio de lo...             43
#
#                                              al_name al_release_date  \
# 0  Nights of the Dead, Legacy of the Beast: Live ...      2020-11-20
# 1  Nights of the Dead, Legacy of the Beast: Live ...      2020-11-20
#
#    al_total_tracks al_album_type  ar_followers_total  tr_duration_ms  \
# 0             17.0         album           6201079.0           38826
# 1             17.0         album           6201079.0          298789
#
#    tr_track_number  danceability  energy  loudness  speechiness  acousticness  \
# 0                1         0.338   0.904   -12.851        0.161       0.43300
# 1                2         0.273   0.997    -4.956        0.126       0.00768
#
#    instrumentalness  liveness  valence    tempo  tf_key  mode  tr_explicit
# 0            0.1340     0.910   0.0394   85.128       5     0        False
# 1            0.0469     0.852   0.0704  127.267       7     1        False

# %% [markdown]
# # Imputing Techniques

# %% [markdown]
# # 1st technique, fillna method

# %%
#imputing popularity column with value of choice

null_dataframe["ar_popularity"][17:33]=null_dataframe["ar_popularity"][17:33].fillna("77")
null_dataframe.iloc[17:33].head(2)
# Out:
# <ipython-input-39-515fb3e20ea6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   null_dataframe["ar_popularity"][17:33]=null_dataframe["ar_popularity"][17:33].fillna("77")
#         ar_name  ar_popularity  \
# 17  Iron Maiden           77.0
# 18  Iron Maiden           77.0
#
#                                               tr_name  tr_popularity  \
# 17  Churchill’s Speech - Live in Mexico City, Pala...             25
# 18  Aces High - Live in Mexico City, Palacio de lo...             28
#
#                                               al_name al_release_date  \
# 17  Nights of the Dead, Legacy of the Beast: Live ...      2020-11-20
# 18  Nights of the Dead, Legacy of the Beast: Live ...      2020-11-20
#
#     al_total_tracks al_album_type  ar_followers_total  tr_duration_ms  \
# 17             17.0         album           6201079.0           38826
# 18             17.0         album           6201079.0          298789
#
#     tr_track_number  danceability  energy  loudness  speechiness  \
# 17                1         0.338   0.904   -12.851        0.161
# 18                2         0.273   0.997    -4.956        0.126
#
#     acousticness  instrumentalness  liveness  valence    tempo  tf_key  mode  \
# 17       0.43300            0.1340     0.910   0.0394   85.128       5     0
# 18       0.00768            0.0469     0.852   0.0704  127.267       7     1
#
#     tr_explicit
# 17        False
# 18        False

# %% [markdown]
# # 2nd technique, replace method

# %%
null_dataframe["ar_popularity"][75:86]=null_dataframe["ar_popularity"][75:86].replace(np.nan,77)

null_dataframe.iloc[75:86].head(2)

# %%
#imputing artist name column with with "artist name" of  choice
null_dataframe["ar_name"][75:80]=null_dataframe["ar_name"][75:80].replace(np.nan,"Iron Maiden")
null_dataframe.iloc[75:80].head(2)

# %% [markdown]
# # 3rd method replace rows based on criteria of other rows

# %%
#imputing artist name column with "artist name" of  choice
null_dataframe["ar_name"]=np.where(null_dataframe["ar_popularity"]==77,
                                            null_dataframe["ar_name"].fillna('Iron Maiden'),
                                            null_dataframe["ar_popularity"])

null_dataframe.iloc[76:86].head(2)
# Out:
#         ar_name  ar_popularity            tr_name  tr_popularity  \
# 76  Iron Maiden           77.0     Speed of Light             52
# 77  Iron Maiden           77.0  The Great Unknown             40
#
#               al_name al_release_date  al_total_tracks al_album_type  \
# 76  The Book of Souls      2015-09-04             11.0         album
# 77  The Book of Souls      2015-09-04             11.0         album
#
#     ar_followers_total  tr_duration_ms  tr_track_number  danceability  energy  \
# 76           6201079.0          301745                2         0.176   0.974
# 77           6201079.0          397655                3         0.211   0.897
#
#     loudness  speechiness  acousticness  instrumentalness  liveness  valence  \
# 76    -5.778        0.132      0.000419          0.000026     0.107   0.3340
# 77    -6.629        0.201      0.019500          0.000189     0.108   0.0702
#
#       tempo  tf_key  mode  tr_explicit
# 76  185.491       7     0        False
# 77   92.082       2     1        False

# %% [markdown]
# ## ADDING NEW FEATURES(variables)

# %%
#Creating new dataframe new_features_added
new_features_added=full

# %% [markdown]
# ### Creating feature "lyrics"

# %%
con = [
    (new_features_added["tf_instrumentalness"]>0.800) & (new_features_added["tf_speechiness"]<0.0400 ),
    new_features_added["tf_instrumentalness"]<0.800 ,
]

# %%
out = ["no_lyrics", "lyrics"]

# %%
result = np.select(con, out)
#pd.Series(result)

# %%
#visualizing how many tracks do have lyrics or not
new_features_added["have_lyrics"]=result
new_features_added.groupby("have_lyrics")["ar_name"].size().plot(kind="bar")

# %% [markdown]
# ### Creating feature "tracks_per_artist"

# %%
#This option will give you a column with repeated values of the counts,


z = new_features_added['ar_name'].value_counts() 

#converts to dictionary
z1 = z.to_dict() 

new_features_added['tracks_per_artist'] = new_features_added['ar_name'].map(z1) 
new_features_added.head(1)
# Out:
#        ar_name  ar_popularity  \
# 0  Iron Maiden           77.0
#
#                                              tr_name  tr_popularity  \
# 0  Churchill’s Speech - Live in Mexico City, Pala...             41
#
#                                              al_name al_release_date  \
# 0  Nights of the Dead, Legacy of the Beast: Live ...      2020-11-20
#
#    al_total_tracks al_album_type  ar_followers_total  tr_duration_ms  \
# 0             17.0         album           6201079.0           38826
#
#    tr_track_number  tf_danceability  tf_energy  tf_loudness  tf_speechiness  \
# 0                1            0.338      0.904      -12.851           0.161
#
#    tf_acousticness  tf_instrumentalness  tf_liveness  tf_valence  tf_tempo  \
# 0            0.433                0.134         0.91      0.0394    85.128
#
#    tf_key  tf_mode  tr_explicit have_lyrics  tracks_per_artist
# 0       5        0        False      lyrics              557.0

# %%
# checking total tracks per artist

new_features_added.groupby("ar_name")["tracks_per_artist"].count().sort_values(ascending=False)
# Out:
# ar_name
# Metallica             815
# Iron Maiden           557
# Blind Guardian        318
# Iced Earth            275
# Bruce Dickinson       215
# Demons & Wizards      129
# Theatre Of Tragedy    121
# Name: tracks_per_artist, dtype: int64

# %%
#Filtering DataFrame by ar_name & total tracks per artist

new_features_added.groupby(["ar_name","tracks_per_artist"]).sum().sort_values(by="tracks_per_artist",ascending=False)

# %% [markdown]
# ## CREATING DATAFRAMES FILTERED BY NEW ADDED FEATURES

# %% [markdown]
# ### Creating "no_lyr" DataFrame , consisting of non lyrics track

# %%
no_lyr=new_features_added[new_features_added["have_lyrics"]=="no_lyrics"]

# %%
no_lyr.shape
# Out:
# (52, 25)

# %% [markdown]
# ### Creating "lyr" DataFrame, consisting of tracks with lyrics

# %%
lyr=new_features_added[new_features_added["have_lyrics"]=="lyrics"]

# %%
lyr.shape
# Out:
# (2698, 25)

# %% [markdown]
# ### Creating "explicit" DataFrame, consisting of tracks with explicit lyrics

# %%
explicit=new_features_added[new_features_added["tr_explicit"]==True]

# %%
explicit.shape
# Out:
# (154, 25)

# %%
explicit.head(2)
# Out:
#         ar_name  ar_popularity  \
# 13  Iron Maiden           77.0
# 30          NaN            NaN
#
#                                               tr_name  tr_popularity  \
# 13  Iron Maiden - Live in Mexico City, Palacio de ...             35
# 30  Iron Maiden - Live in Mexico City, Palacio de ...             20
#
#                                               al_name al_release_date  \
# 13  Nights of the Dead, Legacy of the Beast: Live ...      2020-11-20
# 30                                                NaN             NaN
#
#     al_total_tracks al_album_type  ar_followers_total  tr_duration_ms  \
# 13             17.0         album           6201079.0          330981
# 30              NaN           NaN                 NaN          330981
#
#     tr_track_number  tf_danceability  tf_energy  tf_loudness  tf_speechiness  \
# 13                5            0.137      0.992       -5.179           0.236
# 30               14            0.137      0.992       -5.179           0.236
#
#     tf_acousticness  tf_instrumentalness  tf_liveness  tf_valence  tf_tempo  \
# 13          0.00171               0.0126        0.891       0.148   183.261
# 30          0.00171               0.0126        0.891       0.148   183.261
#
#     tf_key  tf_mode  tr_explicit have_lyrics  tracks_per_artist
# 13       9        0         True      lyrics              557.0
# 30       9        0         True      lyrics                NaN

# %% [markdown]
# ### Creating "non_explicit" DataFrame,, consisting of tracks with non explicit lyrics

# %%
non_explicit=new_features_added[new_features_added["tr_explicit"]==False]

# %%
non_explicit.shape
# Out:
# (2743, 25)

# %% [markdown]
# ## ENCODING ADDED FEATURES("lyrics,explicit_lyrics"), IN BINARY VARIABLES
#
# #### encoding is used to enable further analysis , in order to examine IF & HOW new, added feautres are correlated with each other,
# #### but to the rest of the feautures as well.

# %% [markdown]
# ## Encoding variable "lyrics"

# %%
#  1=lyrics & 0=no_lyrics    

#importing LabelEncoder
from sklearn.preprocessing import LabelEncoder

le=LabelEncoder()
new_features_added["lyr_encoded"]=le.fit_transform(new_features_added["have_lyrics"])

# %% [markdown]
# ## Encoding variable "explicit_lyrics"

# %%
#  1=explicit & 0=non_explicit

from sklearn.preprocessing import LabelEncoder

le=LabelEncoder()
new_features_added["explicit_encoded"]=le.fit_transform(new_features_added["tr_explicit"])

# %%
#Inspecting shape after encoding variables

new_features_added.shape
# Out:
# (2897, 27)

# %%
new_features_added.head(1)
# Out:
#        ar_name  ar_popularity  \
# 0  Iron Maiden           77.0
#
#                                              tr_name  tr_popularity  \
# 0  Churchill’s Speech - Live in Mexico City, Pala...             41
#
#                                              al_name al_release_date  \
# 0  Nights of the Dead, Legacy of the Beast: Live ...      2020-11-20
#
#    al_total_tracks al_album_type  ar_followers_total  tr_duration_ms  \
# 0             17.0         album           6201079.0           38826
#
#    tr_track_number  tf_danceability  tf_energy  tf_loudness  tf_speechiness  \
# 0                1            0.338      0.904      -12.851           0.161
#
#    tf_acousticness  tf_instrumentalness  tf_liveness  tf_valence  tf_tempo  \
# 0            0.433                0.134         0.91      0.0394    85.128
#
#    tf_key  tf_mode  tr_explicit have_lyrics  tracks_per_artist  lyr_encoded  \
# 0       5        0        False      lyrics              557.0            1
#
#    explicit_encoded
# 0                 0

# %%
#creating a new DataFrame "features" including only quantative data thus the  encoded variables as well
#"features" DataFrame will also be later used for machine learning models

features=new_features_added[["ar_popularity","tr_popularity","al_total_tracks",
"ar_followers_total","tr_duration_ms","tr_track_number","tf_danceability","tf_energy","tf_loudness",
"tf_speechiness","tf_acousticness","tf_instrumentalness","tf_liveness","tf_valence","tf_tempo","tf_mode","tf_key",
   "lyr_encoded","explicit_encoded","tracks_per_artist"]]

# %% [markdown]
# ## C.EXLPLORATORY DATA ANALYSIS

# %% [markdown]
# ### EXAMINING CORRELATIONS

# %%
corr = features.corr()
f, ax = plt.subplots(figsize=(12,9))
sns.set(font_scale=1.25)
hm = sns.heatmap(corr, cmap="YlGnBu", annot=True, fmt='.2f', annot_kws={'size': 10})
plt.tight_layout()

# %%
corr.style.background_gradient().set_precision(2)
# Out:
# <style  type="text/css" >
# #T_0876e_row0_col0,#T_0876e_row1_col1,#T_0876e_row2_col2,#T_0876e_row3_col3,#T_0876e_row4_col4,#T_0876e_row5_col5,#T_0876e_row6_col6,#T_0876e_row7_col7,#T_0876e_row8_col8,#T_0876e_row9_col9,#T_0876e_row10_col10,#T_0876e_row11_col11,#T_0876e_row12_col12,#T_0876e_row13_col13,#T_0876e_row14_col14,#T_0876e_row15_col15,#T_0876e_row16_col16,#T_0876e_row17_col17,#T_0876e_row18_col18,#T_0876e_row19_col19{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_0876e_row0_col1{
#             background-color:  #6fa7ce;
#             color:  #000000;
#         }#T_0876e_row0_col2{
#             background-color:  #5c9fc9;
#             color:  #000000;
#         }#T_0876e_row0_col3{
#             background-color:  #034c78;
#             color:  #f1f1f1;
#         }#T_0876e_row0_col4{
#             background-color:  #b1c2de;
#             color:  #000000;
#         }#T_0876e_row0_col5,#T_0876e_row11_col16,#T_0876e_row18_col15{
#             background-color:  #ede8f3;
#             color:  #000000;
#         }#T_0876e_row0_col6,#T_0876e_row1_col15,#T_0876e_row7_col16,#T_0876e_row8_col16,#T_0876e_row11_col1,#T_0876e_row13_col4,#T_0876e_row17_col11,#T_0876e_row17_col15,#T_0876e_row19_col16{
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }#T_0876e_row0_col7{
#             background-color:  #8eb3d5;
#             color:  #000000;
#         }#T_0876e_row0_col8,#T_0876e_row10_col6,#T_0876e_row16_col7{
#             background-color:  #adc1dd;
#             color:  #000000;
#         }#T_0876e_row0_col9,#T_0876e_row2_col18,#T_0876e_row15_col12,#T_0876e_row16_col8{
#             background-color:  #b7c5df;
#             color:  #000000;
#         }#T_0876e_row0_col10,#T_0876e_row3_col12,#T_0876e_row17_col8{
#             background-color:  #99b8d8;
#             color:  #000000;
#         }#T_0876e_row0_col11,#T_0876e_row3_col13,#T_0876e_row4_col1,#T_0876e_row8_col0,#T_0876e_row10_col12,#T_0876e_row11_col0,#T_0876e_row13_col0,#T_0876e_row13_col11,#T_0876e_row15_col13{
#             background-color:  #c6cce3;
#             color:  #000000;
#         }#T_0876e_row0_col12,#T_0876e_row3_col1{
#             background-color:  #81aed2;
#             color:  #000000;
#         }#T_0876e_row0_col13,#T_0876e_row2_col7,#T_0876e_row13_col17,#T_0876e_row16_col9,#T_0876e_row18_col11{
#             background-color:  #cdd0e5;
#             color:  #000000;
#         }#T_0876e_row0_col14,#T_0876e_row2_col15,#T_0876e_row19_col14{
#             background-color:  #f1ebf4;
#             color:  #000000;
#         }#T_0876e_row0_col15,#T_0876e_row4_col18,#T_0876e_row8_col15,#T_0876e_row9_col5,#T_0876e_row9_col15,#T_0876e_row11_col4,#T_0876e_row14_col5{
#             background-color:  #ebe6f2;
#             color:  #000000;
#         }#T_0876e_row0_col16,#T_0876e_row8_col10{
#             background-color:  #faf2f8;
#             color:  #000000;
#         }#T_0876e_row0_col17,#T_0876e_row7_col1,#T_0876e_row7_col15,#T_0876e_row9_col3,#T_0876e_row11_col9{
#             background-color:  #dcdaeb;
#             color:  #000000;
#         }#T_0876e_row0_col18,#T_0876e_row5_col8,#T_0876e_row6_col17,#T_0876e_row7_col19,#T_0876e_row10_col19,#T_0876e_row11_col19,#T_0876e_row15_col11{
#             background-color:  #c1cae2;
#             color:  #000000;
#         }#T_0876e_row0_col19,#T_0876e_row19_col0{
#             background-color:  #023b5d;
#             color:  #f1f1f1;
#         }#T_0876e_row1_col0{
#             background-color:  #4697c4;
#             color:  #000000;
#         }#T_0876e_row1_col2,#T_0876e_row5_col0,#T_0876e_row14_col11{
#             background-color:  #cccfe5;
#             color:  #000000;
#         }#T_0876e_row1_col3,#T_0876e_row11_col10{
#             background-color:  #76aad0;
#             color:  #000000;
#         }#T_0876e_row1_col4,#T_0876e_row4_col12,#T_0876e_row9_col8,#T_0876e_row18_col3{
#             background-color:  #a8bedc;
#             color:  #000000;
#         }#T_0876e_row1_col5,#T_0876e_row5_col1,#T_0876e_row6_col0,#T_0876e_row6_col3,#T_0876e_row6_col12,#T_0876e_row6_col14,#T_0876e_row6_col18,#T_0876e_row6_col19,#T_0876e_row7_col10,#T_0876e_row8_col2,#T_0876e_row8_col11,#T_0876e_row9_col13,#T_0876e_row10_col4,#T_0876e_row10_col7,#T_0876e_row10_col8,#T_0876e_row10_col15,#T_0876e_row11_col17,#T_0876e_row12_col6,#T_0876e_row13_col9,#T_0876e_row15_col16{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }#T_0876e_row1_col6,#T_0876e_row2_col6,#T_0876e_row4_col17,#T_0876e_row8_col9,#T_0876e_row16_col12{
#             background-color:  #c8cde4;
#             color:  #000000;
#         }#T_0876e_row1_col7,#T_0876e_row3_col10,#T_0876e_row19_col10{
#             background-color:  #94b6d7;
#             color:  #000000;
#         }#T_0876e_row1_col8,#T_0876e_row10_col2{
#             background-color:  #86b0d3;
#             color:  #000000;
#         }#T_0876e_row1_col9{
#             background-color:  #d8d7e9;
#             color:  #000000;
#         }#T_0876e_row1_col10,#T_0876e_row3_col18,#T_0876e_row9_col2,#T_0876e_row12_col2,#T_0876e_row14_col9,#T_0876e_row14_col10{
#             background-color:  #b8c6e0;
#             color:  #000000;
#         }#T_0876e_row1_col11,#T_0876e_row9_col18,#T_0876e_row11_col5,#T_0876e_row12_col11,#T_0876e_row15_col17,#T_0876e_row17_col9,#T_0876e_row18_col1{
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }#T_0876e_row1_col12,#T_0876e_row16_col19{
#             background-color:  #d7d6e9;
#             color:  #000000;
#         }#T_0876e_row1_col13,#T_0876e_row16_col6{
#             background-color:  #c0c9e2;
#             color:  #000000;
#         }#T_0876e_row1_col14,#T_0876e_row4_col5,#T_0876e_row16_col18,#T_0876e_row17_col1{
#             background-color:  #e9e5f1;
#             color:  #000000;
#         }#T_0876e_row1_col16,#T_0876e_row3_col16,#T_0876e_row8_col5{
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }#T_0876e_row1_col17,#T_0876e_row5_col4,#T_0876e_row6_col2,#T_0876e_row6_col8,#T_0876e_row7_col14,#T_0876e_row12_col18{
#             background-color:  #d1d2e6;
#             color:  #000000;
#         }#T_0876e_row1_col18,#T_0876e_row6_col7,#T_0876e_row9_col17,#T_0876e_row10_col17,#T_0876e_row14_col19,#T_0876e_row16_col4,#T_0876e_row18_col5{
#             background-color:  #dddbec;
#             color:  #000000;
#         }#T_0876e_row1_col19,#T_0876e_row2_col3{
#             background-color:  #529bc7;
#             color:  #000000;
#         }#T_0876e_row2_col0{
#             background-color:  #60a1ca;
#             color:  #000000;
#         }#T_0876e_row2_col1,#T_0876e_row11_col8,#T_0876e_row12_col14,#T_0876e_row17_col18{
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }#T_0876e_row2_col4{
#             background-color:  #ece7f2;
#             color:  #000000;
#         }#T_0876e_row2_col5,#T_0876e_row9_col11,#T_0876e_row14_col17,#T_0876e_row18_col6{
#             background-color:  #d6d6e9;
#             color:  #000000;
#         }#T_0876e_row2_col8,#T_0876e_row2_col14,#T_0876e_row3_col14,#T_0876e_row8_col3,#T_0876e_row19_col6{
#             background-color:  #f1ebf5;
#             color:  #000000;
#         }#T_0876e_row2_col9,#T_0876e_row15_col2{
#             background-color:  #c2cbe2;
#             color:  #000000;
#         }#T_0876e_row2_col10,#T_0876e_row9_col12{
#             background-color:  #67a4cc;
#             color:  #000000;
#         }#T_0876e_row2_col11{
#             background-color:  #509ac6;
#             color:  #000000;
#         }#T_0876e_row2_col12,#T_0876e_row5_col11,#T_0876e_row7_col0,#T_0876e_row8_col12,#T_0876e_row9_col0,#T_0876e_row12_col10{
#             background-color:  #b0c2de;
#             color:  #000000;
#         }#T_0876e_row2_col13,#T_0876e_row3_col8,#T_0876e_row11_col3,#T_0876e_row15_col9{
#             background-color:  #c5cce3;
#             color:  #000000;
#         }#T_0876e_row2_col16,#T_0876e_row13_col15,#T_0876e_row16_col5,#T_0876e_row18_col14{
#             background-color:  #ede7f2;
#             color:  #000000;
#         }#T_0876e_row2_col17,#T_0876e_row6_col5,#T_0876e_row8_col18,

# %% [markdown]
# ## PLOTTING ECDF's

# %% [markdown]
# ##  Ecdf danceability

# %%
#60% of the tracks have 40% or less danceability meaning that only 40% of tracks have danceabilty >60%
x=np.sort(full["tf_danceability"])
y=np.arange(1,len(x)+1)/len(x)
_=plt.plot(x,y,marker=".",linestyle="none")
_=plt.xlabel("danceability")
_=plt.ylabel("ECDF")
plt.margins(0.02)
plt.show()

# %% [markdown]
# ##  Ecdf valence

# %%
#50% of the tracks have 40% or less valence  

np.sort(full["tf_valence"])
y=np.arange(1,len(x)+1)/len(x)
_=plt.plot(x,y,marker=".",linestyle="none")
_=plt.xlabel("valence")
_=plt.ylabel("ECDF")
plt.margins(0.02)
plt.show()

# %% [markdown]
# ## Ecdf of track popularity

# %%
#80% of the tracks have more than 50% popularity

np.sort(full["tr_popularity"])
y=np.arange(1,len(x)+1)/len(x)
_=plt.plot(x,y,marker=".",linestyle="none")
_=plt.xlabel("track popularity")
_=plt.ylabel("ECDF")
plt.margins(0.02)
plt.show()

# %%
#20% of the tracks have 40% or less energy level

x=np.sort(full["tf_energy"])
y=np.arange(1,len(x)+1)/len(x)
_=plt.plot(x,y,marker=".",linestyle="none")
_=plt.xlabel("energy")
_=plt.ylabel("ECDF")
#plt.margins(0.02)
#plt.show()

# %%
def ecdf(dataframe):
    
    """Compute ECDF """
    # Number of data points: n
    n = len(dataframe)

    # x-data for the ECDF: x
    x = np.sort(dataframe)

    # y-data for the ECDF: y
    y = np.arange(1, n+1) / n

    return x, y

# %%
#COMPARISON OF ECDF's
# Compute ECDFs

x_val, y_val=ecdf(new_features_added["tf_valence"])
x_enrg, y_enrg=ecdf(new_features_added["tf_energy"])
x_danc,y_danc=ecdf(new_features_added["tf_danceability"])
x_instr,y_instr=ecdf(new_features_added["tf_instrumentalness"])

x_acoust,y_acoust=ecdf(new_features_added["tf_acousticness"])
x_speech,y_speech=ecdf(new_features_added["tf_speechiness"])





# Plot all ECDFs on the same plot

_ = plt.plot(x_val, y_val, marker = '.', linestyle = 'none')
_ = plt.plot(x_enrg, y_enrg, marker = '.', linestyle = 'none')
_ = plt.plot(x_danc,y_danc, marker = '.', linestyle = 'none')
_ = plt.plot(x_instr,y_instr, marker = '.', linestyle = 'none')
_ = plt.plot(x_acoust,y_acoust, marker = '.', linestyle = 'none')
_ = plt.plot(x_speech,y_speech, marker = '.', linestyle = 'none')




# Annotate the plot
plt.legend(('valence', 'energy', 'danceability','instrumentalness','acousticness','speechiness','loudness'), loc='lower right')
_ = plt.xlabel('tracks_features')
_ = plt.ylabel('ECDF')


plt.show()

# %% [markdown]
# ## Ecdf "explicit lyrics" feauture

# %%
#  1=explicit & 0=non_explicit
#Only a few songs contain explicit content

x=np.sort(full["explicit_encoded"])
y=np.arange(1,len(x)+1)/len(x)
_=plt.plot(x,y,marker=".",linestyle="none")
_=plt.xlabel("non explicit vs explicit")
_=plt.ylabel("ECDF")
#plt.margins(0.02)
#plt.show()

# %%
#Most numbers of songs have energy between 0.8-1 while most songs are Not danceable
sns.jointplot(x="tf_energy",y="tf_danceability",data=full[["tf_energy","tf_danceability"]],
              kind="hex").set_axis_labels("energy","danceability")

# %%
#Boxploting features

sns.set() # Used to set the default seaborn theme, scaling and colour pallete 

f, axes = plt.subplots(1, 3, sharey=True, figsize=(15, 4))
sns.boxplot(full['ar_popularity'], ax=axes[0])
sns.boxplot(full['tf_acousticness'], ax=axes[1])
sns.boxplot(full['tf_danceability'], ax=axes[2])


f, axes = plt.subplots(1, 3, sharey=True, figsize=(15, 4))
sns.boxplot(full['tf_energy'], ax=axes[0])
sns.boxplot(full['tf_instrumentalness'], ax=axes[1])
sns.boxplot(full['tf_liveness'], ax=axes[2])

f, axes = plt.subplots(1, 3, sharey=True, figsize=(15, 4))
sns.boxplot(full['tf_loudness'], ax=axes[0])
sns.boxplot(full['tf_speechiness'], ax=axes[1])
sns.boxplot(full['tf_tempo'], ax=axes[2])

f, axes = plt.subplots(1, 3, sharey=True, figsize=(15, 4))
sns.boxplot(full['tf_valence'], ax=axes[0])
sns.boxplot(full['tr_track_number'], ax=axes[1])
sns.boxplot(full['tr_duration_ms'], ax=axes[2])



plt.show()

# %% [markdown]
# ## CLEANING DATA AND PREPROCESSING

# %%
#checking num values after feature engineering
new_features_added.isnull().values.sum()
# Out:
# 3736

# %%
new_features_added.isnull().sum()
# Out:
# ar_name                467
# ar_popularity          467
# tr_name                  0
# tr_popularity            0
# al_name                467
# al_release_date        467
# al_total_tracks        467
# al_album_type          467
# ar_followers_total     467
# tr_duration_ms           0
# tr_track_number          0
# tf_danceability          0
# tf_energy                0
# tf_loudness              0
# tf_speechiness           0
# tf_acousticness          0
# tf_instrumentalness      0
# tf_liveness              0
# tf_valence               0
# tf_tempo                 0
# tf_key                   0
# tf_mode                  0
# tr_explicit              0
# have_lyrics              0
# tracks_per_artist      467
# lyr_encoded              0
# explicit_encoded         0
# dtype: int64

# %%
#creating a new dataframe consisting of all the null entries including new features

null_data = new_features_added[new_features_added.isnull().any(axis=1)]
null_data.shape
# Out:
# (467, 27)

# %%
null_data.head(1)
# Out:
#    ar_name  ar_popularity                                            tr_name  \
# 17     NaN            NaN  Churchill’s Speech - Live in Mexico City, Pala...
#
#     tr_popularity al_name al_release_date  al_total_tracks al_album_type  \
# 17             25     NaN             NaN              NaN           NaN
#
#     ar_followers_total  tr_duration_ms  tr_track_number  tf_danceability  \
# 17                 NaN           38826                1            0.338
#
#     tf_energy  tf_loudness  tf_speechiness  tf_acousticness  \
# 17      0.904      -12.851           0.161            0.433
#
#     tf_instrumentalness  tf_liveness  tf_valence  tf_tempo  tf_key  tf_mode  \
# 17                0.134         0.91      0.0394    85.128       5        0
#
#     tr_explicit have_lyrics  tracks_per_artist  lyr_encoded  explicit_encoded
# 17        False      lyrics                NaN            1                 0

# %% [markdown]
# ## Inspecting null data for later investigation

# %%
#null_data.index.tolist()

# %% [markdown]
# ## ANALYSING DATA, FINDING PATTERNS, MAKING AD HOC QUERIES

# %% [markdown]
# ### Creating "analysis" DataFrame that will be used for ad hoc queries.

# %%
analysis=new_features_added

# %% [markdown]
# ## Classifying features --same method can be applied to all features

# %%
high_danc=analysis['tf_danceability']>=0.70
med_danc=(analysis['tf_danceability']>=0.5) & (analysis['tf_danceability']<0.70)
low_danc=analysis['tf_danceability']<0.49

# %%
data=[high_danc.sum(),med_danc.sum(),low_danc.sum()]
danc=pd.DataFrame(data,columns=['counts'],
                   index=['High danceability','Medium Danceability','Low Danceability'])
danc
# Out:
#                      counts
# High danceability         7
# Medium Danceability     461
# Low Danceability       2375

# %% [markdown]
# ## Tracks per Artist

# %% [markdown]
# ## Plotting artists

# %%
analysis.ar_name.value_counts().head(20).plot(kind='barh')
plt.title('Total Tracks per Artist')
plt.show()

# %% [markdown]
# ## Comparing the DataFrames that were created previously based on feature engineering

# %% [markdown]
# ### lyrics VS no_lyrics

# %%
first = pd.DataFrame(lyr.mean(),columns= ['lyrics'])
sec = pd.DataFrame(no_lyr.mean(),columns= ['no_lyrics'])

comparing_lyrics_vs_no_lyrics = pd.concat([first,sec], axis=1)
comparing_lyrics_vs_no_lyrics
# Out:
#                            lyrics     no_lyrics
# ar_popularity        6.950290e+01  6.925490e+01
# tr_popularity        2.481431e+01  1.936538e+01
# al_total_tracks      2.630505e+01  7.205882e+01
# ar_followers_total   7.112694e+06  9.461004e+06
# tr_duration_ms       3.410395e+05  2.634160e+05
# tr_track_number      6.767976e+00  7.750000e+00
# tf_danceability      3.515340e-01  4.683135e-01
# tf_energy            8.790947e-01  6.418077e-01
# tf_loudness         -6.609223e+00 -1.087856e+01
# tf_speechiness       9.855545e-02  3.465769e-02
# tf_acousticness      4.283569e-02  2.190049e-01
# tf_instrumentalness  1.320644e-01  8.970962e-01
# tf_liveness          4.217614e-01  1.937442e-01
# tf_valence           3.040517e-01  4.489250e-01
# tf_tempo             1.237019e+02  1.166208e+02
# tf_key               5.331357e+00  5.557692e+00
# tf_mode              5.203855e-01  5.000000e-01
# tr_explicit          5.522609e-02  0.000000e+00
# tracks_per_artist    5.000013e+02  5.302745e+02

# %% [markdown]
# ### explicit VS non_explicit

# %%
first = pd.DataFrame(explicit.mean(),columns= ['explicit_lyrics'])
sec = pd.DataFrame(non_explicit.mean(),columns= ['non_explicit_lyrics'])

comparing_eng_vs_greek = pd.concat([first,sec], axis=1)
comparing_eng_vs_greek
# Out:
#                      explicit_lyrics  non_explicit_lyrics
# ar_popularity           8.245185e+01         6.892593e+01
# tr_popularity           3.108442e+01         2.415786e+01
# al_total_tracks         6.665926e+01         2.745098e+01
# ar_followers_total      1.486617e+07         6.914302e+06
# tr_duration_ms          3.556776e+05         3.351458e+05
# tr_track_number         8.422078e+00         6.769231e+00
# tf_danceability         2.912727e-01         3.564373e-01
# tf_energy               9.473182e-01         8.661105e-01
# tf_loudness            -6.430195e+00        -6.862825e+00
# tf_speechiness          1.353396e-01         9.501983e-02
# tf_acousticness         4.210731e-02         5.225931e-02
# tf_instrumentalness     1.629692e-01         1.849346e-01
# tf_liveness             6.461721e-01         3.989776e-01
# tf_valence              2.344182e-01         3.117774e-01
# tf_tempo                1.201021e+02         1.237098e+02
# tf_key                  5.967532e+00         5.300766e+00
# tf_mode                 6.168831e-01         5.187751e-01
# tr_explicit             1.000000e+00         0.000000e+00
# tracks_per_artist       7.523333e+02         4.911394e+02

# %% [markdown]
# #  TOP 20 tracks with regards to features

# %%
top_20 = analysis[['ar_name','ar_popularity','tr_name','tr_popularity','al_name','al_release_date','al_album_type',
                     'al_total_tracks', 'ar_followers_total','tr_duration_ms',
                    'tf_danceability','tf_energy','tf_loudness','tf_speechiness','tf_acousticness',
                    'tf_instrumentalness','tf_liveness','tf_valence','tf_tempo','tf_key','tf_mode','tr_explicit','al_album_type']]

# %% [markdown]
# ## Top positive tracks

# %%
top_20[['ar_name',"tr_name",'tf_valence']].sort_values(by='tf_valence',ascending=False).head(20)
# Out:
#                  ar_name                                            tr_name  \
# 829      Bruce Dickinson                            Confeos - 2001 Remaster
# 2598           Metallica  ...And Justice for All - 1988 / From James' Ri...
# 2530           Metallica  ...And Justice for All (1988, From James' Riff...
# 2658           Metallica    Leper Messiah - 1985 / From James' Riff Tapes 2
# 2708           Metallica    Leper Messiah (1985, from James' Riff Tapes II)
# 1008                 NaN                                          Zulu Lulu
# 1018                 NaN                                          Zulu Lulu
# 998      Bruce Dickinson                                          Zulu Lulu
# 2531           Metallica  Eye of the Beholder (1987, From James' Riff Ta...
# 2600           Metallica  Eye of the Beholder - 1987 / From James' Riff ...
# 1869  Theatre Of Tragedy               You Keep Me Hangin' On - Bonus Track
# 1363      Blind Guardian                      Barbara Ann - Remastered 2017
# 1809  Theatre Of Tragedy  Let You Down - Rico Darum & Superdead Remix - ...
# 1039                 NaN                                          Zulu Lulu
# 2599           Metallica  Eye of the Beholder - 1987 / From James' Riff ...
# 2655           Metallica  Disposable Heroes - 1985 / From Kirk's Riff Tapes
# 2705           Metallica   Disposable Heroes (1985, from Kirk's Riff Tapes)
# 1570          Iced Earth                    Cities on Flame - cover version
# 2544           Metallica  …And Justice for All (October 1987, Writing in...
# 828      Bruce Dickinson                         Real World - 2001 Remaster
#
#       tf_valence
# 829        0.970
# 2598       0.968
# 2530       0.967
# 2658       0.932
# 2708       0.924
# 1008       0.902
# 1018       0.902
# 998        0.902
# 2531       0.885
# 2600       0.884
# 1869       0.879
# 1363       0.872
# 1809       0.870
# 1039       0.860
# 2599       0.857
# 2655       0.852
# 2705       0.833
# 1570       0.828
# 2544       0.826
# 828        0.825

# %% [markdown]
# ## Top Sad Tracks

# %%
top_20[['ar_name',"tr_name",'tf_valence']].sort_values(by='tf_valence',ascending=True).head(20)
# Out:
#              ar_name                                            tr_name  \
# 2647       Metallica            Battery - 1985 / From James' Riff Tapes
# 1256  Blind Guardian                          Lammoth - Remastered 2007
# 2697       Metallica             Battery (1985, from James' Riff Tapes)
# 1645      Iced Earth                                  Vengeance Is Mine
# 1575      Iced Earth                 Vengeance Is Mine - live in Athens
# 1222  Blind Guardian                                War of Wrath - Live
# 1236  Blind Guardian              The Bard's Song: In the Forest - Live
# 460      Iron Maiden  Iron Maiden - Live at Donington; 1998 Remaster...
# 2506       Metallica                                The Ecstasy of Gold
# 492              NaN  Iron Maiden - Live at Donington; 1998 Remaster...
# 2589       Metallica                       Battery - Live / Seattle '89
# 2574       Metallica  The Ecstasy of Gold - Metallica Show Intro / L...
# 1500      Iced Earth                                    Setian Massacre
# 2521       Metallica                       Battery (Live - Seattle '89)
# 2525       Metallica                      Whiplash (Live - Seattle '89)
# 1600      Iced Earth              Disciples Of The Lie - live in Athens
# 2593       Metallica                      Whiplash - Live / Seattle '89
# 1986       Metallica  Hardwired - Live In Buenos Aires, Argentina - ...
# 2891       Metallica  Fight Fire With Fire (Live at The Keystone, Pa...
# 1537      Iced Earth                                     Violate - Live
#
#       tf_valence
# 2647      0.0000
# 1256      0.0000
# 2697      0.0000
# 1645      0.0263
# 1575      0.0281
# 1222      0.0299
# 1236      0.0309
# 460       0.0313
# 2506      0.0313
# 492       0.0314
# 2589      0.0317
# 2574      0.0319
# 1500      0.0323
# 2521      0.0323
# 2525      0.0332
# 1600      0.0335
# 2593      0.0339
# 1986      0.0347
# 2891      0.0348
# 1537      0.0354

# %% [markdown]
# ## Top energetic Tracks

# %%
top_20[['ar_name',"tr_name",'tf_energy']].sort_values(by='tf_energy',ascending=False).head(20)
# Out:
#           ar_name                                            tr_name  \
# 1493   Iced Earth                                      Divide Devour
# 428   Iron Maiden          Sanctuary - Live; 1998 Remastered Version
# 491           NaN  2 Minutes To Midnight - Live at Donington; 199...
# 495           NaN  Sanctuary - Live at Donington; 1998 Remastered...
# 405   Iron Maiden          Sanctuary - Live; 1998 Remastered Version
# 459   Iron Maiden  2 Minutes To Midnight - Live at Donington; 199...
# 2858    Metallica  Hit The Lights (Live at Espace Balard, Paris, ...
# 409   Iron Maiden        Iron Maiden - Live; 1998 Remastered Version
# 1482   Iced Earth                            Behold the Wicked Child
# 463   Iron Maiden  Sanctuary - Live at Donington; 1998 Remastered...
# 2350    Metallica                           Last Caress / Green Hell
# 432   Iron Maiden        Iron Maiden - Live; 1998 Remastered Version
# 2323    Metallica                           Last Caress / Green Hell
# 422   Iron Maiden  The Number Of The Beast - Live; 1998 Remastere...
# 103   Iron Maiden  Sanctuary - Live at Birmingham NEC, 1988; 2013...
# 1645   Iced Earth                                  Vengeance Is Mine
# 1     Iron Maiden  Aces High - Live in Mexico City, Palacio de lo...
# 399   Iron Maiden  The Number Of The Beast - Live; 1998 Remastere...
# 554   Iron Maiden  Sanctuary - Live at Birmingham NEC, 1988; 2013...
# 18            NaN  Aces High - Live in Mexico City, Palacio de lo...
#
#       tf_energy
# 1493      0.999
# 428       0.998
# 491       0.998
# 495       0.998
# 405       0.998
# 459       0.998
# 2858      0.998
# 409       0.998
# 1482      0.998
# 463       0.998
# 2350      0.998
# 432       0.998
# 2323      0.998
# 422       0.997
# 103       0.997
# 1645      0.997
# 1         0.997
# 399       0.997
# 554       0.997
# 18        0.997

# %% [markdown]
# ## Top sluggish tracks

# %%
top_20[['ar_name',"tr_name","tr_explicit"]].sort_values(by="tr_explicit",ascending=True).tail(20)
# Out:
#           ar_name                                            tr_name  \
# 2555    Metallica                                          Dyers Eve
# 2356    Metallica                                            So What
# 2358    Metallica                                    Overkill - Live
# 2359    Metallica                                 Damage Case - Live
# 2361    Metallica                           Too Late Too Late - Live
# 451   Iron Maiden  Tailgunner - Live at Donington; 1998 Remastere...
# 2505    Metallica                             Dyers Eve (Remastered)
# 2375          NaN                                               Fuel
# 135   Iron Maiden  The Number of the Beast - Live At Estadio Naci...
# 134   Iron Maiden   Iron Maiden - Live At Estadio Nacional, Santiago
# 438   Iron Maiden         Tailgunner - Live; 1998 Remastered Version
# 2528    Metallica        Blackened (1987, From James' Riff Tapes II)
# 1968    Metallica  Hardwired - Live In São Paulo, Brazil - March ...
# 2526    Metallica                      Breadfan (Live - Seattle '89)
# 2525    Metallica                      Whiplash (Live - Seattle '89)
# 2524    Metallica                    Am I Evil? (Live - Seattle '89)
# 2631    Metallica  Seek & Destroy - Live At The Aragon Ballroom, ...
# 2523    Metallica                   Last Caress (Live - Seattle '89)
# 137   Iron Maiden  Running Free - Live At Estadio Nacional, Santiago
# 1588   Iced Earth                  Angels Holocaust - live in Athens
#
#       tr_explicit
# 2555         True
# 2356         True
# 2358         True
# 2359         True
# 2361         True
# 451          True
# 2505         True
# 2375         True
# 135          True
# 134          True
# 438          True
# 2528         True
# 1968         True
# 2526         True
# 2525         True
# 2524         True
# 2631         True
# 2523         True
# 137          True
# 1588         True

# %% [markdown]
# ## Top accoustic Tracks

# %%
top_20[['ar_name',"tr_name",'tf_acousticness']].sort_values(by='tf_acousticness',ascending=False).head(20)
# Out:
#                ar_name                                            tr_name  \
# 2705         Metallica   Disposable Heroes (1985, from Kirk's Riff Tapes)
# 2655         Metallica  Disposable Heroes - 1985 / From Kirk's Riff Tapes
# 2709         Metallica               Orion (1985, from James' Riff Tapes)
# 2699         Metallica   Master of Puppets (1985, from Kirk's Riff Tapes)
# 2659         Metallica              Orion - 1985 / From James' Riff Tapes
# 2649         Metallica  Master Of Puppets - 1985 / From Kirk's Riff Tapes
# 1755  Demons & Wizards                              Chant - Remaster 2019
# 1792  Demons & Wizards                              Chant - Remaster 2019
# 2647         Metallica            Battery - 1985 / From James' Riff Tapes
# 2697         Metallica             Battery (1985, from James' Riff Tapes)
# 2706         Metallica   Disposable Heroes (1985, from James' Riff Tapes)
# 2656         Metallica  Disposable Heroes - 1985 / From James' Riff Tapes
# 2700         Metallica   Master of Puppets (1985, from James' Riff Tapes)
# 2650         Metallica  Master Of Puppets - 1985 / From James' Riff Tapes
# 2865         Metallica  (Anesthesia) – Pulling Teeth (Live at Espace B...
# 1265    Blind Guardian          Battle of Sudden Flames - Remastered 2007
# 668    Bruce Dickinson            Acoustic Song - 2001 Remastered Version
# 1260    Blind Guardian                         Captured - Remastered 2007
# 2607         Metallica  To Live is to Die - 1988 / From James' Riff Tapes
# 1289    Blind Guardian                  Theatre of Pain - Remastered 2007
#
#       tf_acousticness
# 2705            0.995
# 2655            0.995
# 2709            0.985
# 2699            0.984
# 2659            0.984
# 2649            0.983
# 1755            0.978
# 1792            0.978
# 2647            0.973
# 2697            0.972
# 2706            0.970
# 2656            0.968
# 2700            0.955
# 2650            0.952
# 2865            0.951
# 1265            0.949
# 668             0.937
# 1260            0.928
# 2607            0.925
# 1289            0.925

# %% [markdown]
# ## top popular tracks

# %%
top_20[['ar_name',"tr_name",'tr_popularity']].sort_values(by='tr_popularity',ascending=False).head(20)
# Out:
#           ar_name                               tr_name  tr_popularity
# 2471    Metallica                  Nothing Else Matters             80
# 2464    Metallica                         Enter Sandman             80
# 2476          NaN                         Enter Sandman             75
# 2716    Metallica                     Master Of Puppets             75
# 2467    Metallica                        The Unforgiven             74
# 643   Iron Maiden           The Trooper - 2015 Remaster             73
# 2343    Metallica                    Whiskey In The Jar             73
# 2559    Metallica                                   One             72
# 508   Iron Maiden      Fear of the Dark - 2015 Remaster             71
# 2841          NaN  For Whom The Bell Tolls - Remastered             70
# 2483          NaN                  Nothing Else Matters             70
# 2465    Metallica                          Sad But True             70
# 2500    Metallica                      One (Remastered)             69
# 2792    Metallica            Fade To Black - Remastered             68
# 2666    Metallica        Master of Puppets (Remastered)             68
# 2375          NaN                                  Fuel             67
# 2733    Metallica  For Whom The Bell Tolls (Remastered)             67
# 2479          NaN                        The Unforgiven             66
# 2477          NaN                          Sad But True             65
# 502   Iron Maiden          Wasting Love - 2015 Remaster             65

# %% [markdown]
# ## MOST POPULAR ARTIST

# %%
great=analysis
great=great.sort_values("ar_popularity",ascending=False).drop_duplicates("ar_name").sort_index()

# %%
most_pop=great[["ar_name","ar_popularity"]].sort_values(by="ar_popularity",ascending=False).head(20)
most_pop
# Out:
#                  ar_name  ar_popularity
# 2896           Metallica           85.0
# 1            Iron Maiden           77.0
# 1069      Blind Guardian           59.0
# 718      Bruce Dickinson           56.0
# 1483          Iced Earth           54.0
# 1794    Demons & Wizards           46.0
# 1812  Theatre Of Tragedy           46.0
# 17                   NaN            NaN

# %%
most_pop.plot.bar(x="ar_name",y="ar_popularity", title="Top artist",color="green")


plt.xlabel("Artist Name")
plt.ylabel("Popularity")
plt.show()

# %%
#Tracks popularity
#Creating a "track_popularity" DataFrame
track_popularity=analysis.sort_values("tr_popularity",ascending=False)

# %% [markdown]
# ## Creating a dataframe arranging tracks by popularity

# %%
track_popularity.head(10)
# Out:
#           ar_name  ar_popularity                               tr_name  \
# 2471    Metallica           85.0                  Nothing Else Matters
# 2464    Metallica           85.0                         Enter Sandman
# 2476          NaN            NaN                         Enter Sandman
# 2716    Metallica           85.0                     Master Of Puppets
# 2467    Metallica           85.0                        The Unforgiven
# 643   Iron Maiden           77.0           The Trooper - 2015 Remaster
# 2343    Metallica           85.0                    Whiskey In The Jar
# 2559    Metallica           85.0                                   One
# 508   Iron Maiden           77.0      Fear of the Dark - 2015 Remaster
# 2841          NaN            NaN  For Whom The Bell Tolls - Remastered
#
#       tr_popularity                           al_name al_release_date  \
# 2471             80                         Metallica      1991-08-12
# 2464             80                         Metallica      1991-08-12
# 2476             75                               NaN             NaN
# 2716             75    Master Of Puppets (Remastered)      1986-03-03
# 2467             74                         Metallica      1991-08-12
# 643              73     Piece of Mind (2015 Remaster)            1983
# 2343             73                       Garage Inc.      1998-01-01
# 2559             72            ...And Justice For All      1988-08-25
# 508              71  Fear of the Dark (2015 Remaster)            1992
# 2841             70                               NaN             NaN
#
#       al_total_tracks al_album_type  ar_followers_total  tr_duration_ms  \
# 2471             12.0         album          17257877.0          388266
# 2464             12.0         album          17257877.0          331266
# 2476              NaN           NaN                 NaN          331573
# 2716              8.0         album          17257877.0          515386
# 2467             12.0         album          17257877.0          386493
# 643               9.0         album           6201079.0          252733
# 2343             27.0         album          17257877.0          304693
# 2559              9.0         album          17257877.0          447440
# 508              12.0         album           6201079.0          438120
# 2841              NaN           NaN                 NaN          309973
#
#       tr_track_number  tf_danceability  tf_energy  tf_loudness  \
# 2471                8            0.553      0.362      -11.218
# 2464                1            0.577      0.828       -8.691
# 2476                1            0.579      0.824       -8.710
# 2716                2            0.543      0.836       -9.110
# 2467                4            0.540      0.584       -9.579
# 643                 5            0.285      0.908       -4.601
# 2343                9            0.511      0.970       -3.720
# 2559                4            0.437      0.695       -9.447
# 508                12            0.308      0.866       -5.671
# 2841                3            0.518      0.858       -6.147
#
#       tf_speechiness  tf_acousticness  tf_instrumentalness  tf_liveness  \
# 2471          0.0263         0.045800             0.000006       0.0750
# 2464          0.0298         0.002130             0.011400       0.0581
# 2476          0.0300         0.002060             0.009030       0.0590
# 2716          0.0353         0.000647             0.431000       0.1530
# 2467          0.0254         0.010800             0.002960       0.2530
# 643           0.0705         0.031800             0.009090       0.3110
# 2343          0.0414         0.000006             0.001360       0.1800
# 2559          0.0617         0.001110             0.085700       0.1240
# 508           0.0590         0.000739             0.001410       0.2320
# 2841          0.0672         0.005630             0.003490       0.0598
#
#       tf_valence  tf_tempo  tf_key  tf_mode  tr_explicit have_lyrics  \
# 2471       0.158   142.352       4        0        False      lyrics
# 2464       0.604   123.257       6        0        False      lyrics
# 2476       0.635   123.331       6        0        False      lyrics
# 2716       0.560   105.173       4        0        False      lyrics
# 2467       0.244   139.261       7        1        False      lyrics
# 643        0.669   159.756       4        0        False      lyrics
# 2343       0.566   132.986      10        1        False      lyrics
# 2559       0.413   102.178       7        1        False      lyrics
# 508        0.227   109.825       2        0        False      lyrics
# 2841       0.249   117.897       0        1        False      lyrics
#
#       tracks_per_artist  lyr_encoded  explicit_encoded
# 2471              815.0            1                 0
# 2464              815.0            1                 0
# 2476                NaN            1                 0
# 2716              815.0            1                 0
# 2467              815.0            1                 0
# 643               557.0            1                 0
# 2343              815.0            1                 0
# 2559              815.0            1                 0
# 508               557.0            1                 0
# 2841                NaN            1                 0

# %%
#showing valence in boxplots
#seems Bruce Dickinson's songs to be the happiest whereas Blind Guardian seem to be less happy

plt.figure(figsize=(50,20))
sns.set(font_scale = 2)
_=sns.boxplot(x="ar_name",y="tf_valence", data=analysis)
_=plt.title('Inspecting valence in boxplots',fontsize=10)
_=plt.xlabel("ar_name",fontsize=30)
_=plt.ylabel("valence",fontsize=30)

ax.set_xticklabels(x, rotation=0, fontsize=20)

plt.show()

# %%
#showing how energy is affected due to popularity
# Iron Maiden seem to have the more energetic trakcs whereas Theatre of Tragedy seem to have less energetic tracks

plt.figure(figsize=(50,20))
sns.set(font_scale = 2)
_=sns.boxplot(x="ar_name",y="tf_energy", data=analysis)
_=plt.title('Inspecting energy in boxplots',fontsize=10)
_=plt.ylabel("energy",fontsize=30)

ax.set_xticklabels(x, rotation=0, fontsize=20)

plt.show()

# %% [markdown]
# ## Creating  a new DataFrame "norm", excluding null values.

# %% [markdown]
# ## The DataFrame will be normalized and then used for machine learning and predictive models

# %%
norm=new_features_added[["ar_popularity","tr_popularity","al_total_tracks",
"ar_followers_total","tr_duration_ms","tr_track_number","tf_danceability","tf_energy","tf_loudness",
"tf_speechiness","tf_acousticness","tf_instrumentalness","tf_liveness","tf_valence","tf_tempo","tf_mode",
  "lyr_encoded","explicit_encoded","tracks_per_artist"]]

# %%
#cleaning method=dropping rows with null values

norm.dropna(inplace=True)
# Out:
# <ipython-input-102-f73cef80f1c9>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   norm.dropna(inplace=True)

# %%
#checking that nun values have been eradicated

norm.isnull().sum()
# Out:
# ar_popularity          0
# tr_popularity          0
# al_total_tracks        0
# ar_followers_total     0
# tr_duration_ms         0
# tr_track_number        0
# tf_danceability        0
# tf_energy              0
# tf_loudness            0
# tf_speechiness         0
# tf_acousticness        0
# tf_instrumentalness    0
# tf_liveness            0
# tf_valence             0
# tf_tempo               0
# tf_mode                0
# lyr_encoded            0
# explicit_encoded       0
# tracks_per_artist      0
# dtype: int64

# %% [markdown]
# ### Checking dataset before normalization

# %%
norm.head(5)
# Out:
#    ar_popularity  tr_popularity  al_total_tracks  ar_followers_total  \
# 0           77.0             41             17.0           6201079.0
# 1           77.0             43             17.0           6201079.0
# 2           77.0             41             17.0           6201079.0
# 3           77.0             40             17.0           6201079.0
# 4           77.0             41             17.0           6201079.0
#
#    tr_duration_ms  tr_track_number  tf_danceability  tf_energy  tf_loudness  \
# 0           38826                1            0.338      0.904      -12.851
# 1          298789                2            0.273      0.997       -4.956
# 2          312688                3            0.237      0.996       -4.678
# 3          354165                4            0.219      0.994       -5.088
# 4          556831                5            0.178      0.959       -5.648
#
#    tf_speechiness  tf_acousticness  tf_instrumentalness  tf_liveness  \
# 0          0.1610         0.433000              0.13400        0.910
# 1          0.1260         0.007680              0.04690        0.852
# 2          0.1400         0.000254              0.10200        0.713
# 3          0.1110         0.001240              0.00366        0.944
# 4          0.0951         0.020700              0.01960        0.937
#
#    tf_valence  tf_tempo  tf_mode  lyr_encoded  explicit_encoded  \
# 0      0.0394    85.128        0            1                 0
# 1      0.0704   127.267        1            1                 0
# 2      0.1010   113.782        1            1                 0
# 3      0.1660    96.345        0            1                 0
# 4      0.1590    80.827        1            1                 0
#
#    tracks_per_artist
# 0              557.0
# 1              557.0
# 2              557.0
# 3              557.0
# 4              557.0

# %% [markdown]
# ### Applying normalization method by mean

# %%
norm=norm.apply(lambda x: (x - x.mean()) / x.std())

# %%
norm.aggregate(["mean","std","var"])
# Out:
#       ar_popularity  tr_popularity  al_total_tracks  ar_followers_total  \
# mean  -3.508853e-16   9.356941e-17    -7.017706e-17        9.356941e-17
# std    1.000000e+00   1.000000e+00     1.000000e+00        1.000000e+00
# var    1.000000e+00   1.000000e+00     1.000000e+00        1.000000e+00
#
#       tr_duration_ms  tr_track_number  tf_danceability     tf_energy  \
# mean   -1.023415e-16     2.339235e-17    -1.754427e-16 -1.286579e-16
# std     1.000000e+00     1.000000e+00     1.000000e+00  1.000000e+00
# var     1.000000e+00     1.000000e+00     1.000000e+00  1.000000e+00
#
#        tf_loudness  tf_speechiness  tf_acousticness  tf_instrumentalness  \
# mean -4.678471e-17   -4.678471e-17    -1.169618e-17         7.017706e-17
# std   1.000000e+00    1.000000e+00     1.000000e+00         1.000000e+00
# var   1.000000e+00    1.000000e+00     1.000000e+00         1.000000e+00
#
#        tf_liveness    tf_valence      tf_tempo       tf_mode   lyr_encoded  \
# mean -6.432897e-17 -2.924044e-16  1.169618e-17  7.017706e-17  8.772133e-17
# std   1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# var   1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
#
#       explicit_encoded  tracks_per_artist
# mean      2.339235e-17       2.339235e-17
# std       1.000000e+00       1.000000e+00
# var       1.000000e+00       1.000000e+00

# %% [markdown]
# ### Checking differentiations in values after normalization

# %%
norm.head(5)
# Out:
#    ar_popularity  tr_popularity  al_total_tracks  ar_followers_total  \
# 0       0.507632       1.149592        -0.352085           -0.156201
# 1       0.507632       1.291929        -0.352085           -0.156201
# 2       0.507632       1.149592        -0.352085           -0.156201
# 3       0.507632       1.078423        -0.352085           -0.156201
# 4       0.507632       1.149592        -0.352085           -0.156201
#
#    tr_duration_ms  tr_track_number  tf_danceability  tf_energy  tf_loudness  \
# 0       -2.227422        -1.257379        -0.104965   0.212954    -2.077759
# 1       -0.276531        -1.047686        -0.609786   0.793755     0.695569
# 2       -0.172226        -0.837994        -0.889380   0.787510     0.793223
# 3        0.139039        -0.628301        -1.029176   0.775019     0.649200
# 4        1.659945        -0.418609        -1.347602   0.556438     0.452485
#
#    tf_speechiness  tf_acousticness  tf_instrumentalness  tf_liveness  \
# 0        0.840858         2.226144            -0.230653     1.492458
# 1        0.365873        -0.288557            -0.524500     1.320464
# 2        0.555867        -0.332463            -0.338611     0.908273
# 3        0.162308        -0.326634            -0.670377     1.593281
# 4       -0.053471        -0.211577            -0.616601     1.572524
#
#    tf_valence  tf_tempo   tf_mode  lyr_encoded  explicit_encoded  \
# 0   -1.419157 -1.262617 -1.028175      0.13174         -0.242486
# 1   -1.252614  0.141115  0.972197      0.13174         -0.242486
# 2   -1.088221 -0.308097  0.972197      0.13174         -0.242486
# 3   -0.739019 -0.888957 -1.028175      0.13174         -0.242486
# 4   -0.776625 -1.405892  0.972197      0.13174         -0.242486
#
#    tracks_per_artist
# 0           0.200291
# 1           0.200291
# 2           0.200291
# 3           0.200291
# 4           0.200291

# %% [markdown]
# ## CLUSTER ANALYSIS

# %%
from sklearn.preprocessing import StandardScaler
X = np.array(norm)
scaler = StandardScaler()
scaler.fit(X)
X = scaler.transform(X)

# %%
num_clusters = 5
kmeanModel = KMeans(n_clusters=num_clusters, max_iter=10000, init='k-means++', random_state=123).fit(X)

# %% [markdown]
# ## Covariance Matrix

# %%
import numpy as np
mean_vec = np.mean(X ,axis=0)
cov_mat = (X - mean_vec).T.dot((X - mean_vec)) / (X.shape[0]-1)
print('Covariance matrix \n%s' %cov_mat)

# %%
print('NumPy covariance matrix: \n%s' %np.cov(X.T))

# %% [markdown]
# ## Performing eigendecomposition on the covariance matrix

# %%
cov_mat = np.cov(X.T)

eig_vals, eig_vecs = np.linalg.eig(cov_mat)

print('Eigenvectors \n%s' %eig_vecs)
print('\nEigenvalues \n%s' %eig_vals)

# %%
eig_pairs = [(np.abs(eig_vals[i]), eig_vecs[:,i]) for i in range(len(eig_vals))]

# Sort the (eigenvalue, eigenvector) tuples from high to low
eig_pairs.sort()
eig_pairs.reverse()

# Visually confirm that the list is correctly sorted by decreasing eigenvalues
print('Eigenvalues in descending order:')
for i in eig_pairs:
    print(i[0])
# Out:
# Eigenvalues in descending order:
# 3.732597634271734
# 3.038476272385249
# 1.9084440934980682
# 1.3073262986902745
# 1.1268208099403438
# 1.0780099824285454
# 0.9955770265761616
# 0.883448000977702
# 0.8247415382722321
# 0.7772967608740812
# 0.7149790767804831
# 0.5880231835622063
# 0.49470531034836657
# 0.46445786544033374
# 0.4336323784040921
# 0.38776822562745955
# 0.1883624172290164
# 0.05870727682149483
# 0.004447996904682079

# %% [markdown]
# ## PCA

# %%
from sklearn.decomposition import PCA




pca = PCA(n_components=6, random_state=123)
pca_results = pca.fit_transform(X)

# %%
print(pca.explained_variance_ratio_.sum())
pca.explained_variance_ratio_.cumsum()
# Out:
# 0.641403013388252
# array([0.19637166, 0.35622566, 0.45662875, 0.52540708, 0.58468902,
#        0.64140301])

# %%
pca.n_components_
# Out:
# 6

# %%
pca.explained_variance_ratio_
# Out:
# array([0.19637166, 0.15985399, 0.10040309, 0.06877833, 0.05928194,
#        0.05671399])

# %%
fig, ax = plt.subplots(figsize=(15, 10))
plt.bar(range(len(pca.explained_variance_ratio_)), pca.explained_variance_ratio_, 
        label='Individual', axes=ax, alpha=0.4)
plt.plot(range(len(pca.explained_variance_ratio_)), pca.explained_variance_ratio_.cumsum(), 
         label='Cumulative', color='#576574', axes=ax, marker='o')

ax.set_xticks(range(0,6))
ax.set_xticklabels(range(1,7), fontsize=12)
ax.set_yticklabels(range(0,90,10), fontsize=12)

plt.title('Scree Plot of PCA', fontsize=12)
plt.ylabel('Explained variance (%)', fontsize=12)
plt.xlabel('Principal components', fontsize=12)
plt.legend()
plt.show()

# %%
df_pca = pd.DataFrame(pca_results)
df_pca.columns = ['PC1', 'PC2','PC3','PC4','PC5','PC6']
df_pca['label'] = kmeanModel.labels_
df_pca.head()
# Out:
#         PC1       PC2       PC3       PC4       PC5       PC6  label
# 0  0.639499  1.453666  1.429365 -2.529435 -0.292215  2.193217      0
# 1  1.002070 -1.820771  0.258284 -0.385992 -0.226342  1.426780      0
# 2  1.006313 -1.769827  0.270862 -0.263151 -0.122521  1.195306      0
# 3  1.015823 -1.741140  0.236179 -1.417639 -0.329408  0.184893      0
# 4  1.330988 -1.911247  0.277230 -1.074192  0.223865 -0.051191      0

# %%
#p = ['#DC4E76', '#CC4B93']
sns.set_style('white')
sns.scatterplot(data=df_pca, x='PC1', y='PC2', hue='label', style='label', palette='winter')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.title('Visualisation of Songs using PCA')
plt.show()

# %%
norm.loc[:,'cluster'] = kmeanModel.labels_
artist_cluster_size = norm.groupby('cluster').size().reset_index(name='Num of songs')
sns.barplot(data= artist_cluster_size, x='cluster', y='Num of songs', color='#00BFA5')
plt.title('Distribution of clusters')
plt.show()

# %%
from sklearn.manifold import TSNE
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = Axes3D(fig)

ax.scatter(df_pca['PC1'], df_pca['PC2'], df_pca['PC3'],
           c=df_pca['label'], cmap= 'winter')

ax.set_xlabel('PC1')
ax.set_ylabel('PC2')
ax.set_zlabel('PC3')
plt.show()

# %%
cluster_num = 0
df_cluster1 =norm[norm['cluster'] == cluster_num]
df_cluster1.head()
# Out:
#    ar_popularity  tr_popularity  al_total_tracks  ar_followers_total  \
# 0       0.507632       1.149592        -0.352085           -0.156201
# 1       0.507632       1.291929        -0.352085           -0.156201
# 2       0.507632       1.149592        -0.352085           -0.156201
# 3       0.507632       1.078423        -0.352085           -0.156201
# 4       0.507632       1.149592        -0.352085           -0.156201
#
#    tr_duration_ms  tr_track_number  tf_danceability  tf_energy  tf_loudness  \
# 0       -2.227422        -1.257379        -0.104965   0.212954    -2.077759
# 1       -0.276531        -1.047686        -0.609786   0.793755     0.695569
# 2       -0.172226        -0.837994        -0.889380   0.787510     0.793223
# 3        0.139039        -0.628301        -1.029176   0.775019     0.649200
# 4        1.659945        -0.418609        -1.347602   0.556438     0.452485
#
#    tf_speechiness  tf_acousticness  tf_instrumentalness  tf_liveness  \
# 0        0.840858         2.226144            -0.230653     1.492458
# 1        0.365873        -0.288557            -0.524500     1.320464
# 2        0.555867        -0.332463            -0.338611     0.908273
# 3        0.162308        -0.326634            -0.670377     1.593281
# 4       -0.053471        -0.211577            -0.616601     1.572524
#
#    tf_valence  tf_tempo   tf_mode  lyr_encoded  explicit_encoded  \
# 0   -1.419157 -1.262617 -1.028175      0.13174         -0.242486
# 1   -1.252614  0.141115  0.972197      0.13174         -0.242486
# 2   -1.088221 -0.308097  0.972197      0.13174         -0.242486
# 3   -0.739019 -0.888957 -1.028175      0.13174         -0.242486
# 4   -0.776625 -1.405892  0.972197      0.13174         -0.242486
#
#    tracks_per_artist  cluster
# 0           0.200291        0
# 1           0.200291        0
# 2           0.200291        0
# 3           0.200291        0
# 4           0.200291        0
